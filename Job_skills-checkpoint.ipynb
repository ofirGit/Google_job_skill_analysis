# %%
import nltk
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
#load data
google_df= pd.read_csv('job_skills.csv')
google_df.head()
# Out:
#   Company                                              Title  \
# 0  Google                       Google Cloud Program Manager
# 1  Google  Supplier Development Engineer (SDE), Cable/Con...
# 2  Google  Data Analyst, Product and Tools Operations, Go...
# 3  Google            Developer Advocate, Partner Engineering
# 4  Google     Program Manager, Audio Visual (AV) Deployments
#
#                        Category                          Location  \
# 0            Program Management                         Singapore
# 1  Manufacturing & Supply Chain                   Shanghai, China
# 2           Technical Solutions       New York, NY, United States
# 3           Developer Relations  Mountain View, CA, United States
# 4            Program Management      Sunnyvale, CA, United States
#
#                                     Responsibilities  \
# 0  Shape, shepherd, ship, and show technical prog...
# 1  Drive cross-functional activities in the suppl...
# 2  Collect and analyze data to draw insight and i...
# 3  Work one-on-one with the top Android, iOS, and...
# 4  Plan requirements with internal customers.\nPr...
#
#                               Minimum Qualifications  \
# 0  BA/BS degree or equivalent practical experienc...
# 1  BS degree in an Engineering discipline or equi...
# 2  Bachelor’s degree in Business, Economics, Stat...
# 3  BA/BS degree in Computer Science or equivalent...
# 4  BA/BS degree or equivalent practical experienc...
#
#                             Preferred Qualifications
# 0  Experience in the business technology market a...
# 1  BSEE, BSME or BSIE degree.\nExperience of usin...
# 2  Experience partnering or consulting cross-func...
# 3  Experience as a software developer, architect,...
# 4  CTS Certification.\nExperience in the construc...

# %%
#clean data

# %%
google_df_prep = google_df
google_df_prep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1250 entries, 0 to 1249
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Company                   1250 non-null   object
#  1   Title                     1250 non-null   object
#  2   Category                  1250 non-null   object
#  3   Location                  1250 non-null   object
#  4   Responsibilities          1235 non-null   object
#  5   Minimum Qualifications    1236 non-null   object
#  6   Preferred Qualifications  1236 non-null   object
# dtypes: object(7)
# memory usage: 68.5+ KB

# %%
pd.isnull(google_df_prep).sum()
# Out:
# Company                      0
# Title                        0
# Category                     0
# Location                     0
# Responsibilities            15
# Minimum Qualifications      14
# Preferred Qualifications    14
# dtype: int64

# %%
google_df_prep = google_df_prep.dropna(how='any',axis='rows')

# %%
google_df_prep.Company.value_counts()
# Out:
# Google     1212
# YouTube      23
# Name: Company, dtype: int64

# %%
#create new dataframe without 'YouTube'

df_prep=google_df_prep[google_df_prep.Company != 'YouTube']

# %%
# Chekking in which category Google is hiring

df_prep.Category.value_counts()
# Out:
# Sales & Account Management          167
# Marketing & Communications          161
# Finance                             112
# Technical Solutions                 100
# Business Strategy                    92
# People Operations                    86
# User Experience & Design             83
# Program Management                   72
# Partnerships                         58
# Product & Customer Support           48
# Legal & Government Relations         43
# Administrative                       39
# Sales Operations                     31
# Real Estate & Workplace Services     24
# Software Engineering                 24
# Hardware Engineering                 22
# Manufacturing & Supply Chain         16
# Technical Infrastructure             11
# Network Engineering                   6
# Developer Relations                   5
# IT & Data Management                  5
# Technical Writing                     5
# Data Center & Network                 2
# Name: Category, dtype: int64

# %%
# What are the most popular titles of job?

df_prep.Title.value_counts()
# Out:
# Business Intern 2018                                                                           35
# MBA Intern, Summer 2018                                                                        34
# MBA Intern 2018                                                                                28
# BOLD Intern, Summer 2018                                                                       21
# Field Sales Representative, Google Cloud                                                       17
#                                                                                                ..
# User Engagement Strategy Manager, Google Technical Services, Scaled Engagement and Learning     1
# Director, Global Payroll Operations                                                             1
# Program Manager, Create for Enterprise (Hardware Partnerships)                                  1
# Video Algorithm Engineer                                                                        1
# Head of Inside Sales, Google Cloud (English)                                                    1
# Name: Title, Length: 761, dtype: int64

# %%
# create function to cleaning the text in columns 'Minimum Qualifications' , 'Preferred Qualifications' from stop words, 
# capital leters and other singhs 


from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

def cleanText(column,x,data):
    stopwords=nltk.corpus.stopwords.words('english')
    df=data
    text=df[column].str.lower()
    text=text.str.replace(r'[^\w\s]+', '')
    text=text.str.cat(sep=' ')

    google_df_words = nltk.word_tokenize(text)

    google_df_words_freq = nltk.FreqDist(google_df_words)

    google_df_stopwords = nltk.FreqDist(w for w in google_df_words if w not in stopwords)

    countWords=google_df_stopwords.most_common(x)
    return(countWords)

# %%
cleanText('Minimum Qualifications',50,df_prep)
# Out:
# [('experience', 2965),
#  ('equivalent', 1041),
#  ('degree', 1037),
#  ('practical', 972),
#  ('babs', 811),
#  ('years', 703),
#  ('management', 388),
#  ('ability', 359),
#  ('field', 336),
#  ('working', 308),
#  ('related', 307),
#  ('program', 299),
#  ('2018', 291),
#  ('english', 283),
#  ('speak', 278),
#  ('fluently', 277),
#  ('idiomatically', 275),
#  ('write', 273),
#  ('science', 270),
#  ('technical', 259),
#  ('andor', 251),
#  ('engineering', 233),
#  ('computer', 228),
#  ('work', 206),
#  ('sales', 200),
#  ('business', 180),
#  ('data', 175),
#  ('5', 174),
#  ('development', 169),
#  ('bachelors', 163),
#  ('cloud', 161),
#  ('design', 159),
#  ('2019', 156),
#  ('marketing', 150),
#  ('relevant', 149),
#  ('role', 146),
#  ('10', 145),
#  ('software', 142),
#  ('technology', 141),
#  ('fulltime', 140),
#  ('consulting', 129),
#  ('internship', 129),
#  ('managing', 124),
#  ('june', 123),
#  ('december', 121),
#  ('date', 115),
#  ('must', 113),
#  ('currently', 113),
#  ('3', 112),
#  ('graduation', 110)]

# %%
cleanText('Preferred Qualifications',50,df_prep)
# Out:
# [('experience', 2253),
#  ('ability', 1820),
#  ('skills', 1437),
#  ('management', 692),
#  ('business', 666),
#  ('demonstrated', 634),
#  ('excellent', 558),
#  ('work', 537),
#  ('communication', 516),
#  ('environment', 516),
#  ('strong', 462),
#  ('analytical', 437),
#  ('technical', 436),
#  ('working', 433),
#  ('knowledge', 364),
#  ('technology', 355),
#  ('cloud', 353),
#  ('data', 351),
#  ('sales', 345),
#  ('understanding', 322),
#  ('effective', 318),
#  ('degree', 304),
#  ('project', 298),
#  ('interpersonal', 286),
#  ('complex', 283),
#  ('design', 280),
#  ('marketing', 269),
#  ('related', 267),
#  ('organizational', 256),
#  ('customer', 246),
#  ('written', 246),
#  ('strategic', 245),
#  ('teams', 243),
#  ('multiple', 240),
#  ('relationships', 238),
#  ('technologies', 237),
#  ('andor', 235),
#  ('team', 230),
#  ('projects', 225),
#  ('including', 221),
#  ('analysis', 218),
#  ('industry', 216),
#  ('interest', 214),
#  ('systems', 208),
#  ('managing', 207),
#  ('fastpaced', 205),
#  ('years', 202),
#  ('mba', 193),
#  ('verbal', 192),
#  ('engineering', 190)]

# %%
# Analaysis

# %%
def createDict(lst,df,column):
    dct=dict((j,0) for j in lst)
    for i in lst:
        counter=df[column].str.contains(i).sum()
        if i in lst:
            dct[i]=counter
    return(dct)

# %%
# use 'createDict' function to create dictionary to check how many times those words are appeared and plot it. 

lst=['BA','BS','PhD','Bachelor','MS','Master']

d=createDict(lst,df_prep,'Minimum Qualifications')

degree = sorted(d.items(), key=lambda k: k[1], reverse=True)
df_degree = pd.DataFrame(degree,columns=['Degree','Popularity'])
df_degree.plot.bar(x='Degree',y='Popularity')

# %%
lst=['graduation','internship','Bachelor']
d=createDict(lst,df_prep,'Minimum Qualifications')

stu_degree = sorted(d.items(), key=lambda k: k[1], reverse=True)
stu_degree = pd.DataFrame(stu_degree,columns=['Degree','Popularity'])

stu_degree
# Out:
#        Degree  Popularity
# 0    Bachelor         163
# 1  graduation         108
# 2  internship          96

# %%
explode = (0.1, 0, 0)
fig1, ax1 = plt.subplots()
ax1.pie(stu_degree['Popularity'],explode=explode,labels=stu_degree['Degree'], autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal') 

plt.show()

# %%
#where need Intern

df = df_prep.loc[df_prep.Title.str.contains('Intern').fillna(False)]
df_Intern=pd.DataFrame(df)
country_ct = df_Intern["Location"].str.split(",", n = 1, expand = True)
country_ct.head()

df_Intern['Country']=country_ct[1]
df_Intern['City']=country_ct[0]

df_Intern.head(10)
# Out:
#     Company                                              Title  \
# 226  Google  Internet of Things (IoT) Product Specialist, G...
# 227  Google  Internet of Things (IoT) Product Specialist, G...
# 343  Google         MBA Intern (Korean-English Bilingual) 2018
# 600  Google                           BOLD Intern, Summer 2018
# 606  Google  Operations Manager, International and COO Comm...
# 607  Google                               Business Intern 2018
# 609  Google                               Business Intern 2018
# 610  Google                            MBA Intern, Summer 2018
# 612  Google                               Business Intern 2018
# 615  Google                               Business Intern 2018
#
#                        Category                      Location  \
# 226         Technical Solutions                 Paris, France
# 227         Technical Solutions        London, United Kingdom
# 343           Business Strategy            Seoul, South Korea
# 600                     Finance   New York, NY, United States
# 606  Marketing & Communications  Sunnyvale, CA, United States
# 607  Marketing & Communications            Bucharest, Romania
# 609  Marketing & Communications               Wrocław, Poland
# 610           Business Strategy  Sunnyvale, CA, United States
# 612  Marketing & Communications               Prague, Czechia
# 615  Marketing & Communications               Zagreb, Croatia
#
#                                       Responsibilities  \
# 226  Work as part of the Sales team to identify and...
# 227  Work as part of the Sales team to identify and...
# 343                     Responsibilities vary by role.
# 600  Google interns are given a lot of responsibili...
# 606  Build new programs that can scale with the bus...
# 607  Responsibilities and detailed projects will be...
# 609  Responsibilities and detailed projects will be...
# 610  Google interns are given a lot of responsibili...
# 612  Responsibilities and detailed projects will be...
# 615  Responsibilities and detailed projects will be...
#
#                                 Minimum Qualifications  \
# 226  BA/BS degree in Computer Science, related soft...
# 227  BA/BS degree in Computer Science, related soft...
# 343  Must be pursuing a full-time MBA program with ...
# 600  Be currently enrolled in a 4-year BA/BS progra...
# 606  BA/BS degree or equivalent practical experienc...
# 607  Currently enrolled in a Bachelor's or Master's...
# 609  Currently enrolled in a Bachelor's or Master's...
# 610  Must be pursuing a full-time MBA program with ...
# 612  Currently enrolled in a Bachelor's or Master's...
# 615  Currently enrolled in a Bachelor's or Master's...
#
#                               Preferred Qualifications             Country  \
# 226  Master's degree in Computer Science or other r...              France
# 227  Master's degree in Computer Science or other r...      United Kingdom
# 343  3 years of relevant work experience in the are...         South Korea
# 600  Analytical skills and an interest in taking on...   NY, United States
# 606  Established media relationships and a solid un...   CA, United States
# 607  Previous internship experience in Sales, Adver...             Romania
# 609  Previous internship experience in Sales, Adver...              Poland
# 610  Interest in the technology industry and Google...   CA, United States
# 612  Previous internship experience in Sales, Adver...             Czechia
# 615  Previous internship experience in Sales, Adver...             Croatia
#
#           City
# 226      Paris
# 227     London
# 343      Seoul
# 600   New York
# 606  Sunnyvale
# 607  Bucharest
# 609    Wrocław
# 610  Sunnyvale
# 612     Prague
# 615     Zagreb

# %%
df_Intern['Country'].value_counts()[:10].plot(kind='bar', color='gray')

# %%
lst=['graduation','internship','Bachelor']
dictIntern=createDict(lst,df_Intern,'Minimum Qualifications')

intern_degree = sorted(dictIntern.items(), key=lambda k: k[1], reverse=True)
intern_degree = pd.DataFrame(intern_degree,columns=['Degree','Popularity'])

intern_degree
# Out:
#        Degree  Popularity
# 0  graduation         107
# 1  internship          90
# 2    Bachelor          51

# %%
explode = (0.1, 0, 0)
fig1, ax1 = plt.subplots()
ax1.pie(intern_degree['Popularity'], explode=explode,labels=intern_degree['Degree'], autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
df_Intern['Category'].value_counts().plot(kind='barh')

# %%
lst=['Analyst','Developer']
createDict(lst,df_Intern,'Title')
# Out:
# {'Analyst': 1, 'Developer': 0}

# %%
from wordcloud import WordCloud, ImageColorGenerator
#  The way to print WordCloud efficiently  refer to https://www.kaggle.com/justjun0321/way-to-google-get-a-job-in-goggle-word-cloud.

def wordCloud(word,text,data):
    df=data
    df_subset = df.loc[df.Title.str.contains(word).fillna(False)]
    long_text = ' '.join(df_subset[text].tolist())
    wordcloud = WordCloud(width = 700, height = 700,background_color="white",min_font_size=10).generate(long_text)
    plt.figure(figsize = (5, 5), facecolor = None)
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.margins(x=0, y=0)
    plt.title(text,size=24)
    plt.show()

# %%
wordCloud('Intern','Minimum Qualifications',df_Intern)

# %%
df_Intern['Minimum Qualifications'].value_counts()[:10]

stopwords=nltk.corpus.stopwords.words('english')
text=df_Intern['Minimum Qualifications'].str.lower()
text=text.str.replace(r'[^\w\s]+', '')
text=text.str.cat(sep=' ')

google_df_words = nltk.word_tokenize(text)

google_df_words_dis = nltk.FreqDist(google_df_words)

google_df_stopwords_dis = nltk.FreqDist(w for w in google_df_words if w not in stopwords)

google_df_stopwords_dis.most_common(20)
# Out:
# [('2018', 287),
#  ('program', 259),
#  ('2019', 154),
#  ('fulltime', 140),
#  ('june', 122),
#  ('internship', 122),
#  ('december', 120),
#  ('date', 114),
#  ('currently', 111),
#  ('graduation', 109),
#  ('must', 106),
#  ('enrolled', 101),
#  ('degree', 99),
#  ('able', 95),
#  ('complete', 94),
#  ('graduating', 86),
#  ('returning', 86),
#  ('may', 85),
#  ('united', 83),
#  ('states', 83)]

# %%
wordCloud('Intern','Preferred Qualifications',df_Intern)

# %%
df_prep.columns=['Company', 'Title', 'Category', 'Location', 'Responsibilities',
       'Minimum_Qualifications', 'Preferred_Qualifications']


df = df_prep.loc[df_prep.Minimum_Qualifications.str.contains('Bachelor').fillna(False)]
df_Bachelor=pd.DataFrame(df)

df_Bachelor['Title'].value_counts()[:20]
# Out:
# Business Intern 2018                                                                      35
# Partner Sales Engineer, Google Cloud                                                       7
# User Experience Research Intern, Summer 2018                                               6
# Partner Onboarding Manager (Americas)                                                      6
# User Experience Engineer Intern, Summer 2018                                               4
# Mobile Web Specialist, LCS Central Europe (German)                                         3
# Global Partner Business Development Manager                                                3
# Strategic Cloud Engineer, Google Professional Services                                     2
# Head of Government Channels, Google Cloud                                                  2
# Manager, Measurement & Attribution Specialists, Google Technical Professional Services     2
# Partner Sales Engineer Manager, Google Cloud                                               2
# Customer Success Manager                                                                   2
# Program Manager/Producer, Global Hardware Marketing                                        2
# Business Intern 2017, Australia                                                            2
# Program Manager, Third Party Risk Management (3PRM)                                        2
# Google Cloud Customer Engineer Manager, Financial Services                                 2
# Hardware System Validation Engineer, Consumer Hardware                                     1
# Program Manager, Geo Data Operations                                                       1
# Account Strategist, Google Marketing Solutions Sales (Portuguese)                          1
# ASIC Physical Design Engineering Tech Lead & Manager                                       1
# Name: Title, dtype: int64

# %%
df_Bachelor['Category'].value_counts().plot(kind='barh')

# %%
df_prep.columns=['Company', 'Title', 'Category', 'Location', 'Responsibilities',
       'Minimum Qualifications', 'Preferred Qualifications']

# %%
lst=['SQL','SAS','Python','R','PHP','Java','JavaScript','C','C#']

d=createDict(lst,df_prep,'Minimum Qualifications')

language = sorted(d.items(), key=lambda k: k[1], reverse=True)
df_lang_min = pd.DataFrame(language,columns=['Language','Popularity'])
df_lang_min
df_lang_min.plot.barh(x='Language',y='Popularity')

# %%
df = df_prep.loc[df_prep.Title.str.contains('Analyst').fillna(False)]
df_Analyst=pd.DataFrame(df)
country_ct = df_Analyst["Location"].str.split(",", n = 1, expand = True)
country_ct.head()

df_Analyst['Country']=country_ct[1]
df_Analyst['City']=country_ct[0]

df_Analyst.head()
# Out:
#     Company                                              Title  \
# 2    Google  Data Analyst, Product and Tools Operations, Go...
# 10   Google                    Data Analyst, Consumer Hardware
# 20   Google                  Quantitative Analyst, Ads Quality
# 85   Google        Quantitative Analyst Lead, Trust and Safety
# 182  Google             Quantitative Analyst, Trust and Safety
#
#                        Category                          Location  \
# 2           Technical Solutions       New York, NY, United States
# 10   Product & Customer Support  Mountain View, CA, United States
# 20   Product & Customer Support               Zürich, Switzerland
# 85   Product & Customer Support               Zürich, Switzerland
# 182  Product & Customer Support               Zürich, Switzerland
#
#                                       Responsibilities  \
# 2    Collect and analyze data to draw insight and i...
# 10   Build and maintain the Support Operations Anal...
# 20   Apply advanced statistical methods and work wi...
# 85   Partner with cross-functional stakeholders to ...
# 182  Work with data sets and solve non-routine anal...
#
#                                 Minimum Qualifications  \
# 2    Bachelor’s degree in Business, Economics, Stat...
# 10   BA/BS degree in Computer Science, Engineering,...
# 20   PhD in Statistics or Econometrics or a related...
# 85   PhD degree in Statistics, Econometrics, relate...
# 182  Master's degree in a quantitative discipline o...
#
#                               Preferred Qualifications             Country  \
# 2    Experience partnering or consulting cross-func...   NY, United States
# 10   Experience in designing and executing structur...   CA, United States
# 20   Relevant industry or research experience.\nFam...         Switzerland
# 85   Relevant and extensive PhD research or work ex...         Switzerland
# 182  PhD in a quantitative discipline.\nExperience ...         Switzerland
#
#               City
# 2         New York
# 10   Mountain View
# 20          Zürich
# 85          Zürich
# 182         Zürich

# %%
df_Analyst['Country'].value_counts().plot(kind='barh')

# %%
lst=['SQL','SAS','Python','R','PHP','Java']

d=createDict(lst,df_Analyst,'Preferred Qualifications')

language = sorted(d.items(), key=lambda k: k[1], reverse=True)
df_lang_pref = pd.DataFrame(language,columns=['Language','Popularity'])
df_lang_pref
df_lang_pref.plot.barh(x='Language',y='Popularity')

# %%
lst=['BA','BS','PhD','MS','Master','graduation','internship','Bachelor']
dictAnalyst=createDict(lst,df_Analyst,'Minimum Qualifications')

analyst_degree = sorted(dictAnalyst.items(), key=lambda k: k[1], reverse=True)
analyst_degree = pd.DataFrame(analyst_degree,columns=['Degree','Popularity'])

analyst_degree
# Out:
#        Degree  Popularity
# 0          BA          42
# 1          BS          41
# 2    Bachelor           6
# 3         PhD           5
# 4          MS           4
# 5      Master           2
# 6  internship           1
# 7  graduation           0

# %%
wordCloud('Analyst','Minimum Qualifications',df_Analyst)

# %%
wordCloud('Analyst','Preferred Qualifications',df_Analyst)

# %%
# MadeWordCloud('Developer','Minimum Qualifications')

# %%
df_prep.columns
# Out:
# Index(['Company', 'Title', 'Category', 'Location', 'Responsibilities',
#        'Minimum Qualifications', 'Preferred Qualifications'],
#       dtype='object')

# %%
df_prep.columns=['Company', 'Title', 'Category', 'Location', 'Responsibilities',
       'Minimum_Qualifications', 'Preferred_Qualifications']
